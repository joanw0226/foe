# %%
import numpy as np 
import pandas as pd 
import os.path as op  
import datetime as dt 
import time 

# The default data directory will be '../../data' 
# This can be redefined by the user of the function. 
data_dir = op.join('data') 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import massflow_baseline
reload(massflow_baseline)
# Out:
# <module 'massflow_baseline' from 'massflow_baseline.py'>

# %% [markdown]
# #Cross-check

# %%
hhkerb_reu_la = massflow_baseline.get_hhkerb_reu_la()
hhkerb_reu_la
# Out:
#               Authority  sum_dry_rec
# 0     Blaenau Gwent CBC        1.224
# 1             Conwy CBC      191.780
# 2  Newport City Council      181.490
# 3           Torfaen CBC      195.255

# %%
hhkerb_rec_la = massflow_baseline.get_hhkerb_rec_la()
hhkerb_rec_la
# Out:
# RowText                       Authority  Mixed glass  Mixed Plastic Bottles  \
# 0                     Blaenau Gwent CBC          NaN                    NaN
# 1                          Bridgend CBC     3206.880                    NaN
# 2                        Caerphilly CBC          NaN                    NaN
# 3                Cardiff County Council          NaN                    NaN
# 4        Carmarthenshire County Council          NaN                    NaN
# 5             Ceredigion County Council          NaN                    NaN
# 6          City  and County of Swansea           NaN                    NaN
# 7                             Conwy CBC     3119.250                    NaN
# 8           Denbighshire County Council          NaN                    NaN
# 9             Flintshire County Council     3749.760                1163.00
# 10                      Gwynedd Council     3174.230                 805.62
# 11                  Isle of Anglesey CC     1711.600                 493.68
# 12                   Merthyr Tydfil CBC          NaN                    NaN
# 13                     Monmouthshire CC          NaN                    NaN
# 14                Neath Port Talbot CBC     3139.000                 556.00
# 15                 Newport City Council     3689.120                 984.06
# 16         Pembrokeshire County Council     2322.240                    NaN
# 17                 Powys County Council     3611.444                    NaN
# 18               Rhondda Cynon Taff CBC     7217.650                    NaN
# 19                          Torfaen CBC     2079.910                    NaN
# 20            Vale of Glamorgan Council          NaN                    NaN
# 21                          Wrexham CBC          NaN                    NaN
#
# RowText  Plastics  Steel cans  Aluminium cans  Mixed cans  \
# 0             NaN         NaN             NaN         NaN
# 1        1498.680      513.14          172.44         NaN
# 2             NaN         NaN             NaN         NaN
# 3             NaN         NaN             NaN         NaN
# 4             NaN         NaN             NaN         NaN
# 5             NaN         NaN             NaN         NaN
# 6        3599.840         NaN             NaN         NaN
# 7        1066.460         NaN             NaN      547.92
# 8             NaN         NaN             NaN         NaN
# 9             NaN      413.90          165.22         NaN
# 10         24.820      428.36           94.63         NaN
# 11            NaN         NaN             NaN      307.03
# 12            NaN         NaN             NaN         NaN
# 13            NaN         NaN             NaN         NaN
# 14        724.000         NaN             NaN       84.00
# 15        952.040      567.04          242.85         NaN
# 16            NaN         NaN             NaN         NaN
# 17        194.779         NaN             NaN        0.42
# 18       3991.240         NaN             NaN     1461.95
# 19        817.630      386.49          133.48         NaN
# 20            NaN         NaN             NaN         NaN
# 21            NaN         NaN             NaN         NaN
#
# RowText  Composite food and beverage cartons  Co mingled materials  \
# 0                                        NaN              7111.500
# 1                                        NaN                   NaN
# 2                                        NaN             17828.170
# 3                                        NaN             32416.590
# 4                                        NaN             13012.690
# 5                                        NaN              5418.420
# 6                                        NaN             15855.870
# 7                                        NaN                   NaN
# 8                                        NaN              9720.210
# 9                                        NaN                12.240
# 10                                     17.82                   NaN
# 11                                       NaN                   NaN
# 12                                       NaN              6093.504
# 13                                       NaN             10836.980
# 14                                       NaN                   NaN
# 15                                       NaN                   NaN
# 16                                       NaN              8697.850
# 17                                       NaN              1767.754
# 18                                     23.89              4762.300
# 19                                       NaN                   NaN
# 20                                       NaN             12563.100
# 21                                       NaN              8261.700
#
# RowText  sum_dry_rec
# 0           7112.724
# 1          10763.070
# 2          17828.170
# 3          32774.610
# 4          13012.690
# 5           5424.040
# 6          19455.710
# 7           9171.100
# 8           9720.210
# 9          10907.810
# 10          8570.590
# 11          4496.970
# 12          6093.504
# 13         10836.980
# 14         10407.400
# 15         11520.770
# 16         11020.090
# 17         10273.281
# 18         32346.860
# 19          6478.845
# 20         12563.100
# 21          8261.700

# %%
hhkerb_rec_drs = massflow_baseline.get_hhkerb_rec_drs()
hhkerb_rec_drs
# Out:
# RowText                       Authority  DRS Glass Bottles  \
# 0                     Blaenau Gwent CBC        1137.324568
# 1                          Bridgend CBC        2116.540800
# 2                        Caerphilly CBC        2850.724383
# 3                Cardiff County Council        5240.660139
# 4        Carmarthenshire County Council        2080.729131
# 5             Ceredigion County Council         867.303996
# 6          City  and County of Swansea         3110.968029
# 7                             Conwy CBC        2058.705000
# 8           Denbighshire County Council        1554.261579
# 9             Flintshire County Council        2474.841600
# 10                      Gwynedd Council        2094.991800
# 11                  Isle of Anglesey CC        1129.656000
# 12                   Merthyr Tydfil CBC         974.351290
# 13                     Monmouthshire CC        1732.833102
# 14                Neath Port Talbot CBC        2071.740000
# 15                 Newport City Council        2434.819200
# 16         Pembrokeshire County Council        1532.678400
# 17                 Powys County Council        2383.553040
# 18               Rhondda Cynon Taff CBC        4763.649000
# 19                          Torfaen CBC        1372.740600
# 20            Vale of Glamorgan Council        2008.839690
# 21                          Wrexham CBC        1321.045830
#
# RowText  DRS Plastic Bottles  DRS Ferrous Cans  DRS Aluminium Cans  \
# 0                 475.841236         71.838512          120.062781
# 1                1019.102400         92.365200          137.952000
# 2                1192.704573        180.064517          300.939510
# 3                2192.621409        331.023561          553.235417
# 4                 870.548961        131.428169          219.654207
# 5                 362.868276         54.782804           91.557795
# 6                2051.908800        196.502671          328.412385
# 7                 725.192800         71.996688          118.350720
# 8                 650.282049         98.174121          164.077145
# 9                1116.480000         74.502000          132.176000
# 10                773.395200         77.104800           75.704000
# 11                473.932800         40.343742           66.318480
# 12                407.655418         61.544390          102.858348
# 13                724.993962        109.453498          182.928222
# 14                533.760000        105.114740          175.676912
# 15                944.697600        102.067200          194.280000
# 16                737.244021        111.302909          186.019119
# 17                132.449720        103.760138          173.412983
# 18               2714.043200        192.100230          315.781200
# 19                555.988400         69.568200          106.784000
# 20                840.471390        126.887310          212.065128
# 21                552.707730         83.443170          139.457496
#
# RowText  DRS Beverage Cartons
# 0                   22.049444
# 1                   33.365517
# 2                   55.267327
# 3                  101.601291
# 4                   40.339339
# 5                   16.814524
# 6                   60.312701
# 7                   28.430410
# 8                   30.132651
# 9                   33.814211
# 10                  17.820000
# 11                  13.940607
# 12                  18.889862
# 13                  33.594638
# 14                  32.262940
# 15                  35.714387
# 16                  34.162279
# 17                  31.847171
# 18                  23.890000
# 19                  20.084419
# 20                  38.945610
# 21                  25.611270

# %%
baseline = massflow_baseline.get_massflow_baseline()
